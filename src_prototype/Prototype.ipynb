# %% [raw]
# Train a model:

# %%
from data import create_dataloaders
from model import (
    create_model,
    create_training_components,
)
from train import train_model
from utils import save_model

(
    training_data,
    test_data,
    train_loader,
    test_loader,
) = create_dataloaders()

model = create_model()

loss_fn, optimizer = create_training_components(model)

train_model(
    model,
    train_loader,
    test_loader,
    loss_fn,
    optimizer,
    epochs=5,
)

save_model(model, "test")
# Out:
# Epoch 1
# ------------------------------
# loss: 2.301369 [   64/60000]
# loss: 2.296438 [ 6464/60000]
# loss: 2.288446 [12864/60000]
# loss: 2.288652 [19264/60000]
# loss: 2.280830 [25664/60000]
# loss: 2.281786 [32064/60000]
# loss: 2.274669 [38464/60000]
# loss: 2.282625 [44864/60000]
# loss: 2.265549 [51264/60000]
# loss: 2.253940 [57664/60000]
# Test Error:
# Accuracy: 47.0%, Avg loss: 2.255633
#
# Epoch 2
# ------------------------------
# loss: 2.252119 [   64/60000]
# loss: 2.244673 [ 6464/60000]
# loss: 2.251144 [12864/60000]
# loss: 2.226943 [19264/60000]
# loss: 2.230903 [25664/60000]
# loss: 2.230664 [32064/60000]
# loss: 2.214051 [38464/60000]
# loss: 2.234694 [44864/60000]
# loss: 2.203700 [51264/60000]
# loss: 2.187129 [57664/60000]
# Test Error:
# Accuracy: 60.1%, Avg loss: 2.188810
#
# Epoch 3
# ------------------------------
# loss: 2.182701 [   64/60000]
# loss: 2.170092 [ 6464/60000]
# loss: 2.192438 [12864/60000]
# loss: 2.134820 [19264/60000]
# loss: 2.151962 [25664/60000]
# loss: 2.148905 [32064/60000]
# loss: 2.114878 [38464/60000]
# loss: 2.154240 [44864/60000]
# loss: 2.100172 [51264/60000]
# loss: 2.074831 [57664/60000]
# Test Error:
# Accuracy: 64.8%, Avg loss: 2.075502
#
# Epoch 4
# ------------------------------
# loss: 2.066639 [   64/60000]
# loss: 2.043164 [ 6464/60000]
# loss: 2.086623 [12864/60000]
# loss: 1.980156 [19264/60000]
# loss: 2.013119 [25664/60000]
# loss: 2.004008 [32064/60000]
# loss: 1.944006 [38464/60000]
# loss: 2.010711 [44864/60000]
# loss: 1.920671 [51264/60000]
# loss: 1.881916 [57664/60000]
# Test Error:
# Accuracy: 69.4%, Avg loss: 1.878691
#
# Epoch 5
# ------------------------------
# loss: 1.871706 [   64/60000]
# loss: 1.828053 [ 6464/60000]
# loss: 1.895454 [12864/60000]
# loss: 1.730156 [19264/60000]
# loss: 1.771513 [25664/60000]
# loss: 1.754485 [32064/60000]
# loss: 1.670917 [38464/60000]
# loss: 1.776300 [44864/60000]
# loss: 1.641954 [51264/60000]
# loss: 1.590373 [57664/60000]
# Test Error:
# Accuracy: 72.6%, Avg loss: 1.579585
#
# Done!
# Saved model to /workspace/shared/src_prototype/backups/model_test.pth

# %% [raw]
# Test existing model:

# %%
from data import create_dataloaders
from model import (
    create_model,
    create_training_components,
)
from evaluation import (
    test_model,
    draw_images,
)
from utils import load_model

model = create_model()

load_model(model, "test")

_, test_data, _, test_loader = create_dataloaders()

loss_fn, _ = create_training_components(model)

test_model(
    test_loader,
    model,
    loss_fn,
)

draw_images(
    model,
    test_data,
    cols=5,
    rows=5,
)
# Out:
# Loaded model from /workspace/shared/src_prototype/backups/model_test.pth
# Test Error:
# Accuracy: 72.6%, Avg loss: 1.579585
#
# correct: 18/25 = 72%
